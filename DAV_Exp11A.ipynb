# %% [markdown]
# <a href="https://colab.research.google.com/github/Mtiwari27/DAV_62/blob/main/DAV_Exp11A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aim : Explore Data Visualization libraries in Python and R

# %% [markdown]
# Importing Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import plotly.graph_objects as go

# %% [markdown]
# Loading the Iris dataset

# %%
df = sns.load_dataset('iris')
print(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# 2D Visualization of Dataset

# %%
sns.scatterplot(data=df, x='sepal_length', y='sepal_width', hue='species')
plt.title('Scatter plot of Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()

# %% [markdown]
# 3D Visualization of Dataset

# %%
color_scale = 'Viridis'
color_values = df['petal_length']
fig = go.Figure(data=[go.Scatter3d(x=df['sepal_length'], y=df['sepal_width'], z=df['petal_length'], mode='markers', marker=dict(color=color_values, size=5, colorscale=color_scale))])
fig.update_layout(scene=dict(xaxis_title='X Label', yaxis_title='Y Label', zaxis_title='Z Label'),
                  title='3D Scatter Plot using Plotly')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Conclusion/Outcome :
# a)Identified the Data Visualziation Libraries in Python and R
# b)Performed simple experiments with these libraries in Python and R
